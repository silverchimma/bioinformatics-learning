# %% [markdown]
# <a href="https://colab.research.google.com/github/silverchimma/bioinformatics-learning/blob/main/day1_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Bioinformatics")
# Out:
# Hello, Bioinformatics

# %%
name = "My name is Chimma"
print(name)
# Out:
# My name is Chimma
